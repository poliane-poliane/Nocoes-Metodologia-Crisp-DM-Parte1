# %% [markdown]
# #Praticando tipos, estrutura e controle de fluxo

# %% [markdown]
# ### 01 - Teste de gravidez
# Escreva uma célula com controle de fluxos que tem como premissa a existência das seguintes variáveis:
#
# - ```sexo``` como ```str``` indicando os valores '**M**' para masculino e '**F**' para feminino
# - ```beta_hcg``` que indica a quantidade do beta-HCG no sangue em mUI/mL.
#
# A sua tarefa é escrever um código que imprima como resultado "indivíduo do sexo masculino" quando sexo = 'M', caso sexo = 'F', se o valor de beta-HCG for maior que 5, retorne "Positivo" indicando que a paciente está grávida, e retorne "Negativo" caso contrário.
#
# Não mexa nos valores da variável ```sexo``` nem em ```beta_hcg```, e escreva um código que funcione para quaisquer valores possíveis de ambos: ```sexo``` = '**M**' ou '**F**' e ```beta_hcg``` assumindo valores inteiros positivos.

# %%
sexo = 'f'
beta_hcg = 7.1
# seu código vem abaixo desta linha

# %%
if (sexo == 'M') or (sexo == 'm'):
  print('Indivíduo do sexo masculino')

elif (sexo == 'F') or (sexo == 'f'):
  print('Indivíduo sexo feminino')

else:
  print('Sexo inválido')
# Out:
# Indivíduo sexo feminino

# %% [markdown]
# Outra forma legal de verificar é usando?

# %%
if sexo in ('M', 'm'):
  print('Indivíduo do sexo masculino')

elif sexo in ('F','f'):
  print('Indivíduo sexo feminino')

else:
  print('Sexo inválido')
# Out:
# Indivíduo sexo feminino

# %% [markdown]
# Agora avaliando o beta_hcg:

# %%
if beta_hcg > 5:
  print('Positivo')
elif beta_hcg <= 5:
  print('Negativo')
else:
  print('Valor inválido')
# Out:
# Positivo

# %% [markdown]
# ### 02 - Renomeando variáveis
#
# Vamos ver adiante que uma forma de renomear variáveis de um conjunto de dados é através de dicionários - o dicionário deve conter como chave o nome original, associando a cada chave um único valor (tipo *str*) que contenha o nome novo.
#
# A sua tarefa é escrever um dicionário que possa ser utilizado para traduzir as variáveis ```name``` (nome), ```age``` (idade) e ```income``` (renda). Ou seja, esse dicionário deve relacionar as chaves *name, age* e *income* às suas respectivas traduções.

# %%
dic_renomeacao = {'name': 'nome', 'age': 'idade', 'income': 'renda'}
dic_renomeacao
# Out:
# {'name': 'nome', 'age': 'idade', 'income': 'renda'}

# %% [markdown]
# ### 03 - É divisível?
# A sua tarefa é escrever um código que indique se um número ```N``` é divisível por um número P. Escreva um programa que faça essa verificação para quaisquer combinações de ```N``` e ```M``` e devolva uma mensagem indicativa no output.

# %%
N = 42
M = 7

#Seu código
# Um número é divisível por outro se o resto da divisão inteira dele for zero

if N % M == 0:
  print(f'{N} é divisível por {M}')
else:
  print(f'{N} não é divisível por {M}')
# Out:
# 42 é divisível por 7

# %% [markdown]
# ### 04 - Números primos
# > Um número **N** é primo se e somente se é divisível por 1, -1, por **N** e por -**N**.
#
# Escreva um script que verifica se ```N``` é um número primo, verificando se ```N``` é divisível por todos os números de ```1``` a ```N-1```. Você vai precisar usar alguma ferramenta de *loop* que você aprendeu para isto. No final, devolva uma mensagem no output indicando se o número é primo ou não.

# %%
N = 47

# seu código abaixo
# Todo número é divisível po 1, -1, por si mesmo e pelo seu negativo. Vamos avaliar se entre 1 e N-1 existe ao menos um número tal que divide o número, ou seja, que o resto da divisão inteira é zero
for i in range(1, N-1):
  if N % i == 0:
    print(f'{N} não é primo') # imprime essa mensagem se existir ao menos um valor no intervalo (1, N-1) tal a divisão inteira tenha resto 0
    break # pára de rodar o loop se emcontrar o primeiro número em que isso ocorre
# Out:
# 47 não é primo

# %% [markdown]
# ### 05 - Desafio
# O algorítmo do exercício anterior não é o mais eficiente. O que você pode fazer para deixá-lo mais eficiente? Ou seja, executar menos comparações, portanto consumir menos tempo.
# 1. Será que precisamos correr o loop até o final sempre?
# 2. Será que precisamos mesmo verificar **todos** os números?
# 3. Será que precisamos ir até N-1?
#
# Essas perguntas levam ao tipo de pensamento voltado a deixar um algoritmo mais eficiente. Veja se você consegue melhorar o seu.

# %%
N = 98

# seu código aqui
for i in range (1, N-1):
  if N % i == 0 and i != 1:
    print(f'{N} não é primo, pois {i} é um de seus divisores.')
    break
# Out:
# 98 não é primo, pois 2 é um de seus divisores.

# %% [markdown]
# ### 06 - Peso ideal 1
# O IMC (índice de massa corpórea) é um indicador de saúde mais bem aceito que o peso. Ele é calculado como:
#
# $$ IMC = \dfrac{peso}{altura^2}$$
#
# Segundo a OMS, valores *normais* são entre 18.5 e 24.9.
#
# Sua tarefa é encontrar o ponto médio dessa faixa.

# %%
imc_ideal = (24.9 - 18.5) / 2 + 18.5
imc_ideal
# Out:
# 21.7

# %% [markdown]
# ### 07 - Peso ideal 2
# Recebendo um valor de altura, encontre o peso '*ideal*' dessa pessoa, que fornece o IMC encontrado acima

# %%
altura = 1.70

# Seu código
peso_ideal = imc_ideal * altura ** 2
peso_ideal
# Out:
# 62.712999999999994

# %% [markdown]
# ### 08 - Peso ideal 3
# Dada uma lista contendo as alturas de pacientes, crie uma nova lista que contenha o peso '*ideal*' (que fornece o IMC calculado em **Peso ideal 1**) desses pacientes.

# %%
lista_alturas = [1.95, 2.05, 1.70, 1.65]

lista_peso_ideal = []

# seu código
for i in lista_alturas:
  valor = round(imc_ideal * i**2, 2)
  lista_peso_ideal.append(valor)

lista_peso_ideal
# Out:
# [82.51, 91.19, 62.71, 59.08]

# %% [markdown]
# ### 09 - Peso ideal 4
# Dada uma lista de tuplas - cada elemento da lista é uma tupla contendo altura e peso de um paciente - crie uma nova lista com o IMC desses pacientes.

# %%
altura_peso = [(1.80, 90), (1.65, 75), (1.91, 70)]

imc = []

# seu código

for i in altura_peso:
  imc_unitario = round(i[1] / i[0]**2, 2)
  imc.append(imc_unitario)

imc
# Out:
# [27.78, 27.55, 19.19]

# %% [markdown]
# ### 10 - Peso ideal 5
# Dada uma lista de **listas** - cada elemento da lista é uma **lista** contendo altura e peso de um paciente - adicione mais um elemento à lista de cada paciente contendo o IMC do paciente. Verifique também se é 'baixo', 'normal' ou 'alto' segundo os padrões da OMS em que normal é entre 18.5 e 24.9.
#
# Reflexão: por que no problema anterior temos que criar uma nova lista, e não podemos adicionar os dados de cada indivíduo à tupla?

# %%
altura_peso = [[1.80, 90], [1.65, 75], [1.91, 70]]

# seu código

altura_peso
# Out:
# [[1.8, 90], [1.65, 75], [1.91, 70]]

# %% [markdown]
# Note que para adicionar um elemento x=3 em um elemento da lista, por exemplo, ao primeiro, podemos fazer o seguinte:

# %%
altura_peso[0].append(3)
altura_peso[0]
# Out:
# [1.8, 90, 3]

# %% [markdown]
# Só a título de curiosidade, para remover o elemento que acabamos de adicionar, usamos o método pop:

# %%
altura_peso[0].pop(2)
altura_peso[0]
# Out:
# [1.8, 90]

# %%
altura_peso
# Out:
# [[1.8, 90], [1.65, 75], [1.91, 70]]

# %% [markdown]
# Certo.
#
# Agora note que, caso queiramos definir esse valor x a partir de valores dos elementos da lista menor (a lista contina na lista), podemos acessar os elementos dessa lista menor da seguinte forma:

# %%
print(altura_peso[0][0])
print(altura_peso[0][1])
# Out:
# 1.8
# 90

# %% [markdown]
# Portanto, para calcular o imc_unitário, ou seja, de cada elemento da lista menor, podemos fazer o seguinte:

# %%
for i in range(0,3,1):
  imc_unitario = round(altura_peso[i][1]/(altura_peso[i][0]**2), 2)
  print(imc_unitario)
  i+=1
# Out:
# 27.78
# 27.55
# 19.19

# %% [markdown]
# Agora vamos precisar adicionar/appendar esses elementos à cada lista menor.

# %%
for i in range(0,3,1):
  altura_peso[i].append(round(altura_peso[i][1]/(altura_peso[i][0]**2), 2))
  i+=1
altura_peso
# Out:
# [[1.8, 90, 27.78], [1.65, 75, 27.55], [1.91, 70, 19.19]]

# %% [markdown]
# Essa é uma forma. Mas há uma maneira mais simples de fazer tudo de uma vez, visto como segue. Vou só escrever o codigo, mas não vou rodar porque o resultado vai se sobrepor ao resultado feito nos passos acima:

# %%
for i in range(0,3,1):
  altura_peso[i].append(round(altura_peso[i][1]/(altura_peso[i][0]**2), 2))
  i+=1
altura_peso
# Out:
# [[1.8, 90, 27.78], [1.65, 75, 27.55], [1.91, 70, 19.19]]

# %% [markdown]
# Perfeito.
#
# Agora vamos para a parte da classificação do IMC (baixo, normal, alto).
#
# De modo geral, precisamos usar uma estrutura semelhante à abaixo:

# %%
if (imc <18.5):
  print('Baixo')
elif (imc >= 18.5) and (imc <= 24.9):
  print('Normal')
else:
  print('Alto')

# %% [markdown]
# Mas para acessar o valor o imc, vamos precisar acessar os elementos da seguinte forma altura_peso[i][2]. Portanto:

# %%
altura_peso

for i in range(0,3,1):
  if (altura_peso[i][2] <18.5):
    print('Baixo')
  elif (altura_peso[i][2] >= 18.5) and (altura_peso[i][2] <= 24.9):
    print('Normal')
  else:
    print('Alto')
# Out:
# Alto
# Alto
# Normal
